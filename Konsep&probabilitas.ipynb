# %% [markdown]
# <a href="https://colab.research.google.com/github/nova888/Data-Science/blob/master/Konsep%26probabilitas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np

np.random.seed(0)
throws = np.random.randint(1, 7, size=10000)
even_count = np.sum(throws % 2 == 0)
probability_even = even_count / len(throws)
print(f"Simulated probability of rolling an even number: {probability_even}")
# Out:
# Simulated probability of rolling an even number: 0.5085

# %%
np.random.seed(0)
X = np.random.normal(loc=0, scale=1, size=1000)
Y = np.random.normal(loc=0, scale=1, size=1000)

covarian_matrix = np.cov(X, Y)
covariance = covarian_matrix[0, 1]
print(f"covariance: {covariance}")
# Out:
# covariance: -0.030139636457206343

# %%
# Distribusi Uniform

import matplotlib.pyplot as plt

np.random.seed(0)
uniform_data = np.random.uniform(0, 1, 1000)
plt.hist(uniform_data, bins=30, color='lightblue', edgecolor='black')
plt.title('Distribusi Uniform')
plt.xlabel('Nilai')
plt.ylabel('Frekuensi')
plt.show()

# %%
# Distribusi Binomial

binomial_data = np.random.binomial(n=10, p=0.5, size=1000)
plt.hist(binomial_data, bins=20, color='lightgreen', edgecolor='black')
plt.title('Distribusi Binomial')
plt.xlabel('Nilai')
plt.ylabel('Frekuensi')
plt.show()

# %%
#Distribusi Poisson

poisson_data = np.random.poisson(lam=3, size=1000)
plt.hist(poisson_data, bins=30, color='lightblue', edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()

# %%
#Distribusi Normal

normal_data = np.random.normal(loc=0, scale=1, size=1000)
plt.hist(normal_data, bins=30, color='lightblue', edgecolor='black')
plt.xlabel('Values')
plt.ylabel('Frequency')
plt.show()
